# %% [markdown]
# # In Class Notebook, Week 04

# %% [markdown]
# You can access this notebook in near-real time by going here (be sure to refresh page!): https://github.com/UIUC-iSchool-DataViz/is445_bcu_fall2026/blob/main/week04/inClass_week04.ipynb
#
# **Remember:**
# 1. This is near-real time (updates every 15 seconds)
# 1. Refresh your browser to see the updates on github

# %%
# import our usual things
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

# %%
buildings = pd.read_csv("https://github.com/UIUC-iSchool-DataViz/is445_data/raw/main/building_inventory.csv", 
                       na_values = {
                           'Square Footage':0,
                           'Year Acquired':0,
                           'Year Constructed':0,
                           'Total Floors':0
                       })

# %%
#buildings.columns

# %%
stats = buildings.groupby('Year Acquired')['Square Footage'].describe()
#stats

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.plot(stats['max'], marker='.', linewidth=2.0)
ax.set_xlabel('Year Acquired')
ax.set_ylabel('Square Footage')
ax.set_yscale('log')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.plot(stats['max'], marker='.', linewidth=2.0, label='Max')
ax.plot(stats['min'], marker='.', linewidth=2.0, label='Min')
ax.set_xlabel('Year Acquired')
ax.set_ylabel('Square Footage')
ax.set_yscale('log')
ax.legend()
plt.show()

# %%
with plt.style.context('ggplot'):
    # selected everything and then did CMD+]
    fig, ax = plt.subplots(figsize=(10,2))
    ax.plot(stats['max'], marker='.', linewidth=2.0, label='Max')
    ax.plot(stats['min'], marker='.', linewidth=2.0, label='Min')
    ax.set_xlabel('Year Acquired')
    ax.set_ylabel('Square Footage')
    ax.set_yscale('log')
    ax.legend()
    plt.show()

# %% [markdown]
# # In Class Notebook, Week 05
#
# You can access this notebook in near-real time by going here (be sure to refresh page!): https://github.com/UIUC-iSchool-DataViz/is445_bcu_fall2026/blob/main/week05/inClass_week05.ipynb
#
# **Remember:**
# 1. This is near-real time (updates every 15 seconds)
# 1. Refresh your browser to see the updates on github

# %%
import ipywidgets

# %%
islider = ipywidgets.IntSlider(min=0,max=10, step=1, orientation='vertical')

# %%
# islider

# %%
cp = ipywidgets.ColorPicker()

# %%
# cp

# %%
ipywidgets.link( (cp, 'value'), (islider.style, 'handle_color') )

# %%
ipywidgets.HBox([cp,islider])

# %%
class MyObject():
    name = 'unnamed'
    age = 0

# %%
my_obj = MyObject()

# %%
my_obj.name, my_obj.age
# Out:
# ('unnamed', 0)

# %%
my_obj.name = 'Bob'
my_obj.age = 47

# %%
my_obj.name, my_obj.age
# Out:
# ('Bob', 47)

# %%
import traitlets

# %%
# class MyObject():
#     name = 'unnamed'
#     age = 0

class MyTraitletObject(traitlets.HasTraits):
    name = traitlets.Unicode('unnamed') # trailet-specific way of saying "string"
    age = traitlets.Int(0) # traitlets specific way of saying "int"

# %%
my_t_obj = MyTraitletObject()

# %%
my_t_obj.name, my_t_obj.age
# Out:
# ('unnamed', 0)

# %%
my_t_obj.name = 'Bob'
my_t_obj.age = 47

# %%
my_t_obj.name, my_t_obj.age
# Out:
# ('Bob', 47)

# %%
def name_change(change): # event for buttons? change?
    print(change)

my_t_obj.observe(name_change, ['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# {'name': 'name', 'old': 'Bob', 'new': 'Linda', 'owner': <__main__.MyTraitletObject object at 0x108f01f60>, 'type': 'change'}

# %%
def name_change2(change):
    print("Hello, my name is", change['new'], 'and I am', change['owner'].age, 'years old.')

my_t_obj.observe(name_change2, ['name'])

# %%
my_t_obj.name = 'Bob'
# Out:
# {'name': 'name', 'old': 'Linda', 'new': 'Bob', 'owner': <__main__.MyTraitletObject object at 0x108f01f60>, 'type': 'change'}
# Hello, my name is Bob and I am 47 years old.

# %%
my_t_obj.unobserve(name_change,['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# Hello, my name is Linda and I am 47 years old.

# %%
my_t_obj = MyTraitletObject() # the "lazy" way to only observe what you want

def name_change2(change):
    print("Hello, my name is", change['new'], 'and I am', change['owner'].age, 'years old.')

my_t_obj.observe(name_change2, ['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# Hello, my name is Linda and I am 0 years old.

# %%
def age_change(change):
    print("Hello, my name is", change['owner'].name, 'and I am', change['new'], 'years old.')

my_t_obj.observe(age_change, ['age'])

# %%
my_t_obj.age = 42
# Out:
# Hello, my name is Linda and I am 42 years old.

# %%
my_t_obj.name = 'Bob'
my_t_obj.age = 47
# Out:
# Hello, my name is Bob and I am 42 years old.
# Hello, my name is Bob and I am 47 years old.

# %% [markdown]
# ## Intro to bqplot

# %%
import numpy as np
import bqplot

# %%
# 1. Read in (make) data
x = np.arange(100)
y = np.random.random(100)

# %%
# y

# %%
# 2. Scales
# bqplot.LinearScale?
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# %%
# 3. Axis
#bqplot.Axis?
ax_x = bqplot.Axis(scale = x_sc, label='X Value')
ax_y = bqplot.Axis(scale = y_sc, label = 'Y Value', orientation='vertical')

# %%
# 4. Mark
#bqplot.Lines?
lines = bqplot.Lines(x=x,y=y, scales = {'x':x_sc,'y':y_sc})

# %%
# 5. interactivity would be added

# %%
# 6. Put it all together in a figure
fig = bqplot.Figure(marks=[lines], axes = [ax_x, ax_y])

# %%
fig
# Out:
# Figure(axes=[Axis(label='X Value', scale=LinearScale(), side='bottom'), Axis(label='Y Value', orientation='ver…

# %%
# 1. Read in (make) data
x = np.arange(100)
y = np.random.random(100)

# 2. Scales
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# 3. Axis
ax_x = bqplot.Axis(scale = x_sc, label='X Value')
ax_y = bqplot.Axis(scale = y_sc, label = 'Y Value', orientation='vertical')

# 4. Mark
lines = bqplot.Lines(x=x,y=y, scales = {'x':x_sc,'y':y_sc})

# 5. interactivity would be added

# 6. Put it all together in a figure
fig = bqplot.Figure(marks=[lines], axes = [ax_x, ax_y])
fig
# Out:
# Figure(axes=[Axis(label='X Value', scale=LinearScale()), Axis(label='Y Value', orientation='vertical', scale=L…

# %%
bqplot.interacts.PanZoom?
# Out:
# Init signature: bqplot.interacts.PanZoom(*args: 't.Any', **kwargs: 't.Any') -> 't.Any'
# Docstring:
# An interaction to pan and zoom wrt scales.
#
# Attributes
# ----------
# allow_pan: bool (default: True)
#     Toggle the ability to pan.
# allow_zoom: bool (default: True)
#     Toggle the ability to zoom.
# scales: Dictionary of lists of Scales (default: {})
#     Dictionary with keys such as 'x' and 'y' and values being the scales in
#     the corresponding direction (dimensions) which should be panned or
#     zoomed.
# Init docstring: Public constructor
# File:           /opt/anaconda3/envs/DataViz/lib/python3.10/site-packages/bqplot/interacts.py
# Type:           MetaHasTraits
# Subclasses:

# %%
# 1. Read in (make) data
x = np.arange(100)
y = np.random.random(100)

# 2. Scales
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# 3. Axis
ax_x = bqplot.Axis(scale = x_sc, label='X Value')
ax_y = bqplot.Axis(scale = y_sc, label = 'Y Value', orientation='vertical')

# 4. Mark
lines = bqplot.Lines(x=x,y=y, scales = {'x':x_sc,'y':y_sc})

# 5. interactivity would be added
pz = bqplot.interacts.PanZoom(scales={'x':[x_sc], 'y':[y_sc]})

# 6. Put it all together in a figure
fig = bqplot.Figure(marks=[lines], axes = [ax_x, ax_y], interaction=pz)
fig
# Out:
# Figure(axes=[Axis(label='X Value', scale=LinearScale()), Axis(label='Y Value', orientation='vertical', scale=L…

# %% [markdown]
# ### Scatter plot example

# %%
# 1. make/collect data
x = np.random.random(100)
y = np.random.random(100)

# %%
# 2. scales
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# %%
# 3. Axes
ax_x = bqplot.Axis(scale=x_sc, label='X')
ax_y = bqplot.Axis(scale=y_sc, label='Y', orientation='vertical')

# %%
# 4. marks
# bqplot.Scatter?
scatters = bqplot.Scatter(x=x,y=y, scales={'x':x_sc, 'y':y_sc})

# %%
# 5. interactivity?

# %%
# 6. put it all together in figure
fig = bqplot.Figure(marks=[scatters], axes=[ax_x,ax_y])
fig
# Out:
# Figure(axes=[Axis(label='X', scale=LinearScale(), side='bottom'), Axis(label='Y', orientation='vertical', scal…

# %%
# 1. make/collect data
x = np.random.random(100)
y = np.random.random(100)

# 2. scales
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# 3. Axes
ax_x = bqplot.Axis(scale=x_sc, label='X')
ax_y = bqplot.Axis(scale=y_sc, label='Y', orientation='vertical')

# 4. marks
scatters = bqplot.Scatter(x=x,y=y, scales={'x':x_sc, 'y':y_sc})

# 5. interactivity?

# 6. put it all together in figure
fig = bqplot.Figure(marks=[scatters], axes=[ax_x,ax_y])
fig
# Out:
# Figure(axes=[Axis(label='X', scale=LinearScale()), Axis(label='Y', orientation='vertical', scale=LinearScale()…

# %%
# bqplot.interacts.FastIntervalSelector?

# %%
# 1. make/collect data
x = np.random.random(100)
y = np.random.random(100)

# 2. scales
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# 3. Axes
ax_x = bqplot.Axis(scale=x_sc, label='X')
ax_y = bqplot.Axis(scale=y_sc, label='Y', orientation='vertical')

# 4. marks
scatters = bqplot.Scatter(x=x,y=y, scales={'x':x_sc, 'y':y_sc})

# 5. interactivity - select an interval on x-axis
selector = bqplot.interacts.FastIntervalSelector(scale=x_sc, marks=[scatters])

# 6. put it all together in figure
fig = bqplot.Figure(marks=[scatters], axes=[ax_x,ax_y], interaction=selector)
fig
# Out:
# Figure(axes=[Axis(label='X', scale=LinearScale()), Axis(label='Y', orientation='vertical', scale=LinearScale()…

# %%
selector.selected
# Out:
# array([0.09913002, 0.20434386])

# %%
scatters.selected_style = {'fill':'red', 'stroke':'yellow'}

# %% [markdown]
# ## 2D heatmap (random data)
# Working toward multi-dimension linked views

# %%
# 1. data
data = np.random.random((10,10))
# data

# 2. scales
# bqplot.ColorScale?
col_sc = bqplot.ColorScale()

# 3. axis

# 4. marks
bqplot.GridHeatMap?
# Out:
# Init signature: bqplot.GridHeatMap(**kwargs)
# Docstring:
# GridHeatMap mark.
#
# Alignment: The tiles can be aligned so that the data matches either the
# start, the end or the midpoints of the tiles. This is controlled by the
# align attribute.
#
# Suppose the data passed is a m-by-n matrix. If the scale for the rows is
# Ordinal, then alignment is by default the mid points. For a non-ordinal
# scale, the data cannot be aligned to the mid points of the rectangles.
#
# If it is not ordinal, then two cases arise. If the number of rows passed
# is m, then align attribute can be used. If the number of rows passed
# is m+1, then the data are the boundaries of the m rectangles.
#
# If rows and columns are not passed, and scales for them are also
# not passed, then ordinal scales are generated for the rows and columns.
#
# Attributes
# ----------
# row_align: Enum(['start', 'end'])
#     This is only valid if the number of entries in `row` exactly match the
# ...

# %% [markdown]
# # In Class Notebook, Week 02

# %% [markdown]
# You can access this notebook in near-real time by going here: https://github.com/UIUC-iSchool-DataViz/is445_bcu_fall2026/blob/main/week02/inClass_week02.ipynb

# %%
print(5+4)
# Out:
# 9

# %%
6+7
# Out:
# 13

# %%
# this is a comment

# %% [markdown]
# I pressed `ESC+m` to make this a markdown cell
#
# I can press `RETURN` to go down in the cell, but `SHIFT+RETURN` is needed to run the cell
#
# # This is a header!
#
# ## This is a subheader
#
# I can make an ordered list with the `*` symbol:
# * thing 1
# * thing 2
# * thing 3
#
# Also make an ordered list:
# 1. ordered 1
# 1. ordered 2

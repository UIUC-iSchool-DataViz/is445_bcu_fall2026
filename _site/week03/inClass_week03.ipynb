# %% [markdown]
# # In Class Notebook, Week 03

# %% [markdown]
# You can access this notebook in near-real time by going here (be sure to refresh page!): https://github.com/UIUC-iSchool-DataViz/is445_bcu_fall2026/blob/main/week03/inClass_week03.ipynb
#
# **Remember:**
# 1. This is near-real time (updates every 15 seconds)
# 1. Refresh your browser to see the updates on github

# %%
import matplotlib.pyplot as plt # SHIFT + RETURN
import PIL.Image as Image # only import Image function

# %%
#!conda install wget --yes

# %%
#!wget https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/stitch_reworked.png

# %%
#!ls
#!dir

# %%
# im = Image.open('/Users/jnaiman/Downloads/stitch_reworked.png') # on my mac, downloaded
im = Image.open('stitch_reworked.png') # if using wget command

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
#im # does a quick display of image

# %%
import numpy as np

# %%
im_data = np.array(im)

# %%
im_data.shape # 483 rows, 430 columns, 4 color channels -- R=red, G=green, B=blue, A=alpha/opacity
# Out:
# (483, 430, 4)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0]) # [:,:,0] = all pixels in all rows and columns in Red color channel
plt.show()

# %%
im_data[:,:,0].shape
# Out:
# (483, 430)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten()) # [:,:,0] = all pixels in all rows and columns in Red color channel
plt.show()

# %%
im_data[:,:,0].flatten().shape
# Out:
# (207690,)

# %%
np.unique(im_data[:,:,0])
# Out:
# array([  0, 126, 255], dtype=uint8)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256) # [:,:,0] = all pixels in all rows and columns in Red color channel
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax.set_xlabel('Red channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax.hist(im_data[:,:,1].flatten(), bins=256, color='green')
ax.set_xlabel('Red channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax.hist(im_data[:,:,1].flatten(), bins=256, color='green')
ax.hist(im_data[:,:,2].flatten(), bins=256, color='blue')
ax.hist(im_data[:,:,3].flatten(), bins=256, color='gray') # A, alpha, opacity = set as gray
ax.set_xlabel('Red channel bins')
ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize=(10,6))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green')
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue')
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # A, alpha, opacity = set as gray
#ax.set_xlabel('Red channel bins')
#ax.set_ylabel('# of pixels per bin')
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize=(10,6))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green')
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue')
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # A, alpha, opacity = set as gray
ax[0].set_xlabel('Red channel bins')
ax[1].set_xlabel('Green channel bins')
ax[2].set_xlabel('Blue channel bins')
ax[3].set_xlabel('Opacity channel bins')
for a in ax:
   a.set_ylabel('# of pixels per bin')
fig.tight_layout() # fits all plots in tightest layout without overlaps
plt.show()

# %%
fig, ax = plt.subplots(5, 1, figsize=(10,6))
ax[0].hist(im_data[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax[1].hist(im_data[:,:,1].flatten(), bins=256, color='green')
ax[2].hist(im_data[:,:,2].flatten(), bins=256, color='blue')
ax[3].hist(im_data[:,:,3].flatten(), bins=256, color='gray') # A, alpha, opacity = set as gray
ax[0].set_xlabel('Red channel bins')
ax[1].set_xlabel('Green channel bins')
ax[2].set_xlabel('Blue channel bins')
ax[3].set_xlabel('Opacity channel bins')
for a in ax[:-1]:
   a.set_ylabel('# of pixels per bin')
    
ax[4].imshow(im_data)

fig.tight_layout() # fits all plots in tightest layout without overlaps
plt.show()

# %% [markdown]
# ## More complex image
#
# (I did `ESC+m` to change this into markdown)

# %%
# !wget https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/littleCorgiInHat.png
# Out:
# --2026-09-08 11:34:24--  https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/littleCorgiInHat.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 553572 (541K) [image/png]
# Saving to: ‘littleCorgiInHat.png.1’
#
# littleCorgiInHat.pn 100%[===================>] 540.60K  --.-KB/s    in 0.02s
#
# 2026-09-08 11:34:25 (22.0 MB/s) - ‘littleCorgiInHat.png.1’ saved [553572/553572]

# %%
#!ls

# %%
im2 = Image.open('littleCorgiInHat.png')

# %%
# im2

# %%
im_data2 = np.array(im2)

# %%
plt.imshow(im_data2)

# %%
im_data2.shape
# Out:
# (625, 499, 4)

# %%
fig, ax = plt.subplots(4, 1, figsize=(10,6))
ax[0].hist(im_data2[:,:,0].flatten(), bins=256, color='red') # [:,:,0] = all pixels in all rows and columns in Red color channel
ax[1].hist(im_data2[:,:,1].flatten(), bins=256, color='green')
ax[2].hist(im_data2[:,:,2].flatten(), bins=256, color='blue')
# ax[3].hist(im_data2[:,:,3].flatten(), bins=256, color='gray') # A, alpha, opacity = set as gray
ax[0].set_xlabel('Red channel bins')
ax[1].set_xlabel('Green channel bins')
ax[2].set_xlabel('Blue channel bins')
# ax[3].set_xlabel('Opacity channel bins')
for a in ax[:-1]:
   a.set_ylabel('# of pixels per bin')
   a.set_ylim(0,15000)
    
ax[3].imshow(im_data2)

fig.tight_layout() # fits all plots in tightest layout without overlaps
plt.show()
